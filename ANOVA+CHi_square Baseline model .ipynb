# %%
# !pip install pycaret
# !pip install lightgbm
import pandas as pd
import pycaret
import time

from pycaret.classification import *

# %%
def readData():
    # Read in the feature selected dataset
    Anova = pd.read_csv('https://raw.githubusercontent.com/Spandanabendi/MentalAid/main/ANOVA_fs_train.csv')
    chi_sq= pd.read_csv('https://raw.githubusercontent.com/Spandanabendi/MentalAid/main/chi2_fs_train.csv')
    data = pd.merge(Anova, chi_sq, on='Unnamed: 0')
    # If necessary, drop any of the columns with unique values
    data2 = data.drop(columns=['Label_x'])
    return data2

# %%
# %%time
dataDf = readData()
dataDf.head()
# Out:
# Wall time: 125 ms
#    Unnamed: 0  JWTRNS_8.0    HISP_2    HISP_4   HISP_21   HISP_24  \
# 0           0    0.001129  0.022240  0.001693  0.000113  0.003161
# 1           1    0.001810  0.227774  0.002001  0.000397  0.008461
# 2           2    0.000765  0.013889  0.000000  0.000127  0.002294
# 3           3    0.000446  0.012902  0.000609  0.000189  0.001672
# 4           4    0.000746  0.037820  0.000474  0.000068  0.002711
#
#    OCCP_6240.0  OCCP_9830.0   RAC1P_3   RAC1P_7   RAC1P_9  RACASN_0  RACASN_1  \
# 0     0.000790     0.000452  0.003838  0.001016  0.025514  0.961955  0.038045
# 1     0.001001     0.000677  0.069848  0.002398  0.033828  0.958197  0.041803
# 2     0.000255     0.001529  0.050076  0.000510  0.019241  0.990316  0.009684
# 3     0.000437     0.000231  0.001063  0.000309  0.024106  0.977008  0.022992
# 4     0.000441     0.000576  0.005829  0.001796  0.023519  0.985665  0.014335
#
#     RACNH_0   RACNH_1  RACNUM_1  RACNUM_2  RACNUM_3  RACNUM_4   RACPI_0  \
# ...

# %%
dataDf.shape
# Out:
# (50, 39)

# %%
# %%time
# Set up the experiment for dataset
exp1 = setup(dataDf, target='Label_y')
# Out:
# <style  type="text/css" >
# </style><table id="T_4175b2cc_a074_11eb_89da_d0abd5bac1b4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4175b2cc_a074_11eb_89da_d0abd5bac1b4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4175b2cc_a074_11eb_89da_d0abd5bac1b4row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_4175b2cc_a074_11eb_89da_d0abd5bac1b4row0_col1" class="data row0 col1" >3124</td>
#             </tr>
#             <tr>
#                         <th id="T_4175b2cc_a074_11eb_89da_d0abd5bac1b4level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4175b2cc_a074_11eb_89da_d0abd5bac1b4row1_col0" class="data row1 col0" >Target</td>
# ...

# %%
# Compare the models built with different algorithms and their performance metric
compare_models()
# Out:
# <style  type="text/css" >
#     #T_503f7cb4_a074_11eb_8ddb_d0abd5bac1b4 th {
#           text-align: left;
# ...
